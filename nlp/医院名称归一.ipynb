# %%
import pandas as pd
from tqdm import tqdm

# %%
guiyi = pd.read_excel('/Users/litianhao/Desktop/filebase/医院归一.xlsx')
guiyi_tongyi = guiyi[guiyi['备注'] == '同义']
guiyi_tongyi_name = pd.DataFrame(guiyi_tongyi,columns=['推荐.1','Unnamed: 3'])
guiyi_tongyi_name
# Out:
#                      推荐.1               Unnamed: 3
# 32           中国医学科学院血液病医院            中国医学科学院血液学研究所
# 33                   唐都医院               空军军医大学唐都医院
# 34                   西京医院               空军军医大学西京医院
# 35                   西南医院               陆军军医大学西南医院
# 36                山东省肿瘤医院       山东省肿瘤医院暨山东省肿瘤防治研究院
# 37               上海儿童医学中心      上海交通大学医学院附属上海儿童医学中心
# 38                   仁济医院          上海交通大学医学院附属仁济医院
# 39                   新华医院          上海交通大学医学院附属新华医院
# 40      北部战区总医院(原沈阳军区总医院)                  沈阳军区总医院
# 41                   安贞医院           首都医科大学附属北京安贞医院
# 42                 北京朝阳医院           首都医科大学附属北京朝阳医院
# 43                 北京儿童医院           首都医科大学附属北京儿童医院
# 44                  世纪坛医院          首都医科大学附属北京世纪坛医院
# 45                 北京天坛医院           首都医科大学附属北京天坛医院
# 46                 北京同仁医院           首都医科大学附属北京同仁医院
# 47                 北京友谊医院           首都医科大学附属北京友谊医院
# 48                   宣武医院               首都医科大学宣武医院
# ...

# %%
processed = pd.read_excel('/Users/litianhao/Desktop/processed/completed/hospital-node_mapping_简称maybe.xlsx')

# %%
processed
# Out:
#                Unnamed: 0       Unnamed: 1                 Unnamed: 2  \
# 0                     NaN              NaN  s:Hospital:isOrganization
# 1                  create              NaN                     create
# 2                hospital         hospital               organization
# 3              s:Hospital       s:Hospital             s:Organization
# 4              xsd:string       xsd:string                  s:Text.zh
# 5                     NaN  s:gradeAndClass                     s:name
# 6                  安徽省立医院             三级甲等                     安徽省立医院
# 7            安徽医科大学第一附属医院             三级甲等               安徽医科大学第一附属医院
# 8                    北医六院             三级甲等                       北医六院
# 9                    北医三院             三级甲等                       北医三院
# 10                   北大医院             三级甲等                       北大医院
# 11                 北大口腔医院             三级甲等                     北大口腔医院
# ...

# %%
for i,x in zip(guiyi_tongyi_name['推荐.1'],guiyi_tongyi_name['Unnamed: 3']):
    processed.loc[[processed['Unnamed: 0'] == i][0],'Unnamed: 0'] =x
    processed.loc[[processed['Unnamed: 2'] == i][0],'Unnamed: 2'] =x

# %%
processed.to_excel('/Users/litianhao/Desktop/processed/completed/hospital-node_mapping_guiyi.xlsx',index=None,header=None)

# %%
processed_doctor = pd.read_excel('/Users/litianhao/Desktop/processed/completed/doctor-node_mapping.xlsx')
processed_doctor
# Out:
#                Unnamed: 0                  Unnamed: 1  \
# 0                     NaN                         NaN
# 1                  create                         NaN
# 2                  doctor                      doctor
# 3                s:Doctor                    s:Doctor
# 4              xsd:string                   s:Text.zh
# 5                     NaN  s:professionalTitleAndRank
# 6            安徽省立医院肿瘤科陈曼萍                       副主任医师
# 7           安徽省立医院神经内科罗六一                        主治医师
# 8       安徽省立医院干部医疗保健中心康冬梅                     主任医师 教授
# 9             安徽省立医院小儿科林杨                        主治医师
# 10            安徽省立医院普外科赵涛                       副主任医师
# 11         安徽省立医院预防保健科卜韵梅                        主治医师
# 12           安徽省立医院神经内科吴蕾                       副主任医师
# 13            安徽省立医院ICU刘宝                        主任医师
# 14           安徽省立医院肾脏内科任伟                     主任医师 教授
# 15            安徽省立医院血液科周莉                       副主任医师
# ...

# %%
for i,x in zip(guiyi_tongyi_name['推荐.1'],guiyi_tongyi_name['Unnamed: 3']):
    processed_doctor.loc[[processed_doctor['Unnamed: 13'] == i][0],'Unnamed: 13'] =x
    processed_doctor.loc[[processed_doctor['Unnamed: 14'] == i][0],'Unnamed: 14'] =x

# %%
processed_doctor
# Out:
#                Unnamed: 0                  Unnamed: 1  \
# 0                     NaN                         NaN
# 1                  create                         NaN
# 2                  doctor                      doctor
# 3                s:Doctor                    s:Doctor
# 4              xsd:string                   s:Text.zh
# 5                     NaN  s:professionalTitleAndRank
# 6            安徽省立医院肿瘤科陈曼萍                       副主任医师
# 7           安徽省立医院神经内科罗六一                        主治医师
# 8       安徽省立医院干部医疗保健中心康冬梅                     主任医师 教授
# 9             安徽省立医院小儿科林杨                        主治医师
# 10            安徽省立医院普外科赵涛                       副主任医师
# 11         安徽省立医院预防保健科卜韵梅                        主治医师
# 12           安徽省立医院神经内科吴蕾                       副主任医师
# 13            安徽省立医院ICU刘宝                        主任医师
# 14           安徽省立医院肾脏内科任伟                     主任医师 教授
# 15            安徽省立医院血液科周莉                       副主任医师
# ...

# %%
processed_doctor.to_excel('/Users/litianhao/Desktop/processed/completed/doctor-node_mapping.xlsx',index=None,header=None)
